# %% [markdown]
# ##Construcción de un Web Scrapper##

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.latarde.com.mx/'

# %%
##Peticion o request a la pagina##
latarde = requests.get(url)

# %%
latarde.status_code #un status de 200 es una respuesta exitosa
# Out:
# 200

# %%
print(latarde.text)
# Out:
# <!--blob 10/09/2023 10:14:21.563 p. m.  --><!--publishThread: 09:55:17.491 PM  --><!DOCTYPE html><!--[if IE 8]><html class="no-js lt-ie9" lang="en" > <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"><!--<![endif]--><head><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta property="fb:pages" content="189279551191344" /><link rel='manifest' href='https://latarderm.blob.core.windows.net.optimalcdn.com/espanol/manifest.json?v=3'><title> La Tarde de Reynosa - Noticias en L&iacute;nea </title><meta name="Description" content=" La Tarde de Reynosa - Noticias de Reynosa, Tamaulipas." /><meta name="Keywords" content="la tarde, La Tarde, La Tarde de Reynosa, latarde.com.mx, El Manana, Pharr, El manana.com" /><meta name="abstract" content=" La Tarde de Reynosa - Noticias de Reynosa, Tamaulipas." /><meta name="news_keywords" content="la tarde, La Tarde, La Tarde de Reynosa, latarde.com.mx, El Manana, Pharr, El manana.com" /><link rel=
# ...

# %%
print(latarde.headers)
# Out:
# {'Date': 'Tue, 10 Oct 2023 04:14:21 GMT', 'Server': 'Optimal CDN', 'Content-Type': 'text/html; charset=utf-8', 'Access-Control-Allow-Methods': '*', 'X-sacs-edtsite': 'www.latarde.com.mx', 'X-AspNet-Version': '4.0.30319', 'X-Storage': 'RAM', 'X-Backend': 'www_latarde_com_mx_ssl', 'X-Connection': 'keep-alive', 'Cache-Control': 'public,max-age=0', 'Strict-Transport-Security': 'max-age=31536000', 'Expires': 'Wed, 11 Oct 2023 04:14:21 GMT', 'Content-Encoding': 'gzip', 'Age': '82', 'X-Cache-Hits': '1', 'X-Cache': 'HIT', 'X-TTL': '86317.095', 'X-Powered-By': 'SACSPro', 'X-Host': 'www.latarde.com.mx', 'X-UA': 'default', 'X-UA-Device': 'desktop', 'Vary': 'X-UA,X-UA-Device,X-Forwarded-Proto,X-Country-Code', 'X-Forwarded-For': '201.174.236.109', 'X-Real-IP': '201.174.236.109', 'X-TMP-IP': '', 'X-WAF': '', 'X-Source-IP': '', 'X-Country-Code': 'MX', 'X-City': 'Ciudad JuÃ¡rez', 'X-Apache': 'Yes', 'X-url': '/', 'X-Node': 'node01.sanjose', 'X-Balancer': 'lb02.sanjose', 'Access-Control-Allow-Origin':
# ...

# %%
##Preprocesamiento(transformacion)
s = BeautifulSoup(latarde.text,'lxml')
s
# Out:
# <!--blob 10/09/2023 10:14:21.563 p. m.  --><!--publishThread: 09:55:17.491 PM  --><!DOCTYPE html>
# ...

# %%
print(s.prettify())
# Out:
# <!--blob 10/09/2023 10:14:21.563 p. m.  -->
# <!--publishThread: 09:55:17.491 PM  -->
# <!DOCTYPE html>
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en" > <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="189279551191344" property="fb:pages"/>
#   <link href="https://latarderm.blob.core.windows.net.optimalcdn.com/espanol/manifest.json?v=3" rel="manifest"/>
#   <title>
#    La Tarde de Reynosa - Noticias en Línea
#   </title>
#   <meta content=" La Tarde de Reynosa - Noticias de Reynosa, Tamaulipas." name="Description"/>
#   <meta content="la tarde, La Tarde, La Tarde de Reynosa, latarde.com.mx, El Manana, Pharr, El manana.com" name="Keywords"/>
#   <meta content=" La Tarde de Reynosa - Noticias de Reynosa, Tamaulipas." name="abstract"/>
# ...

# %%
secciones = s.find_all("meta",{"content":"La Tarde"})
secciones
# Out:
# [<meta content="La Tarde" property="og:site_name"/>]

# %% [markdown]
# Construcción de Scrapper clase#2

# %%
import requests
from bs4 import BeautifulSoup #Procesammiento de página y obtener contenido

# %%
url = 'https://www.pagina12.com.ar/'

# %%
#Peticion de URL
p12 = requests.get(url) #get, post, put delete

# %%
p12.status_code #un status code de 200 es una respuesta exitosa
# Out:
# 200

# %%
print(p12.text)
# Out:
# <!-- DUST PATH: /usr/src/app/src/templates/home.dust/ --><!-- DUST PATH: /usr/src/app/src/templates/p12_layout.dust/ --><!DOCTYPE html><html class="no-js " lang="es"><head><meta charset="utf-8"><title>Página | 12: La otra mirada sobre Argentina y el mundo</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><link rel="canonical" href="https://www.pagina12.com.ar"><script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script async="async" src="https://s-adzone.com/c/14_p12.js"></script><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","name": "Página|12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","http
# ...

# %%
print(p12.headers)
# Out:
# {'Date': 'Tue, 10 Oct 2023 04:45:50 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'vary': 'Accept-Encoding', 'x-dns-prefetch-control': 'off', 'strict-transport-security': 'max-age=15724800; includeSubDomains', 'x-download-options': 'noopen', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'x-etag': 'W/"85d68-hOo9JKmNriQwp8BxqWmVETSSyZg"', 'x-backend': 'frontend', 'x-type': 'Dynamic URI', 'x-backend-ttl': '120.000', 'Age': '58', 'grace': '86400.000 none', 'ttl': '61.057', 'x-instance': 'cache-front-prod-varnish-6dc75c954-p5q9w', 'x-restarts': '0', 'x-cache': 'hit cached', 'CF-Cache-Status': 'DYNAMIC', 'Server': 'cloudflare', 'CF-RAY': '813c375658db16be-IAH', 'Content-Encoding': 'br'}

# %%
#Preprocesamos (Transformación)
s = BeautifulSoup(p12.text,'lxml')

# %%
#imprime de manera legible lo que trajo
print(s.prettify())
# Out:
# <!-- DUST PATH: /usr/src/app/src/templates/home.dust/ -->
# <!-- DUST PATH: /usr/src/app/src/templates/p12_layout.dust/ -->
# <!DOCTYPE html>
# <html class="no-js" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Página | 12: La otra mirada sobre Argentina y el mundo
#   </title>
#   <meta content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg" name="google-site-verification"/>
#   <link href="https://www.pagina12.com.ar" rel="canonical"/>
#   <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script async="async" src="https://s-adzone.com/c/14_p12.js">
#   </script>
#   <script type="application/ld+json">
# ...

# %%
## Conocemos las secciones o links del menu
secciones = s.find_all("a",{"class":"p12-dropdown-item"})
secciones
# Out:
# [<a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-pais">El país</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/economia">Economía</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Espectáculos</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ciencia">Ciencia</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cultura">Cultura</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/buenos-aires12">Buenos Aires12</a>,
# ...

# %%
#Obtenemos cada elemento de las secciones.
#<a href="url o link">Texto</a>
link_sections = [item.get('href') for item in secciones]
title_sections = [item.get_text() for item in secciones]

# %%
link_sections
# Out:
# ['https://www.pagina12.com.ar/secciones/el-pais',
#  'https://www.pagina12.com.ar/secciones/economia',
#  'https://www.pagina12.com.ar/secciones/sociedad',
#  'https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos',
#  'https://www.pagina12.com.ar/secciones/deportes',
#  'https://www.pagina12.com.ar/secciones/el-mundo',
#  'https://www.pagina12.com.ar/secciones/ciencia',
#  'https://www.pagina12.com.ar/secciones/cultura',
#  'https://www.pagina12.com.ar/secciones/buenos-aires12',
#  'https://www.pagina12.com.ar/suplementos/rosario12',
#  'https://www.pagina12.com.ar/secciones/salta12',
#  'https://www.pagina12.com.ar/secciones/catamarca12',
#  'https://www.pagina12.com.ar/secciones/la-rioja12',
#  'https://www.pagina12.com.ar/secciones/negrx',
#  'https://www.pagina12.com.ar/secciones/universidad-diario',
#  'https://www.pagina12.com.ar/secciones/audiovisuales',
#  'https://www.pagina12.com.ar/secciones/plastica',
#  'https://www.pagina12.com.ar/secciones/psicologia',
# ...

# %%
title_sections
# Out:
# ['El país',
#  'Economía',
#  'Sociedad',
#  'Espectáculos',
#  'Deportes',
#  'El mundo',
#  'Ciencia',
#  'Cultura',
#  'Buenos Aires12',
#  'Rosario12',
#  'Salta12',
#  'Catamarca12',
#  'La Rioja12',
#  'Negrx',
#  'Universidad',
#  'Audiovisuales',
#  'Plástica',
#  'Psicología',
#  'Soci@s',
#  'La ventana',
#  'Contratapa',
#  'Diálogos',
#  'Recordatorios',
#  'Edición impresa',
#  'Cultura y Espectáculos',
#  'Cash',
#  'Radar',
#  'Radar Libros',
#  'NO',
#  'Soy',
#  'Las12',
#  'Verano12',
#  'Líbero',
#  'Especiales de P12',
#  'GO Noticias',
#  'AM750',
#  'Malena',
#  'Latinoamérica Piensa']

# %%
#Buscamos la noticias del pais
sections_news = requests.get('https://www.pagina12.com.ar/secciones/el-pais')
if sections_news.status_code==200:
    bs_news = BeautifulSoup(sections_news.text,'lxml')

# %%
bs_news
# Out:
# <!-- DUST PATH: /usr/src/app/src/templates/section_amp.dust/ --><!-- DUST PATH: /usr/src/app/src/templates/p12_layout_lists_amp.dust/ --><!-- DUST PATH: /usr/src/app/src/templates/page_amp.dust/ --><!DOCTYPE html>
# ...

# %%
div_news = bs_news.find_all("div",{"class":"articles-list"})

# %%
len(div_news)
news = div_news[1] #get the list of items

# %%
content_news = news.find_all('article',{'class':'article-item'})

# %%
content_news
# Out:
# [<article class="article-item article-item--teaser"><!-- Image --><div class="article-item__header"><a aria-label="Ir a la nota Diputados: El oficialismo busca busca aprobar el programa Compra sin IVA y su propia ley de Alquileres" href="/596700-diputados-el-oficialismo-busca-busca-aprobar-el-programa-com"><!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ --><amp-img alt="Diputados: El oficialismo busca busca aprobar el programa Compra sin IVA y su propia ley de Alquileres (Fuente: Prensa Diputados)" class="" height="200" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2023-10/776622-10-a-prensadiputados.jpg?h=bd660f6b&amp;itok=TJH6tmfg" width="300"><noscript><img alt="Diputados: El oficialismo busca busca aprobar el programa Compra sin IVA y su propia ley de Alquileres (Fuente: Prensa Diputados)" height="200" src="https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2023-10/776622-10-a-pren
# ...
